# %% [markdown]
# # Chapter 6 - Bonus

# %% [markdown]
# In this chapter, we are going to modify our code to make changes to the game.<br>
# First, let's load all functions again first.

# %% [markdown]
# ### Importing Pygame

# %%
import pygame
pygame.init()
print("Pygame imported!")

# %% [markdown]
# ### `jump()`

# %%
def jump():
    global bird_vel
    bird_vel = -10   
print("jump() loaded!")

# %% [markdown]
# ### `randomGap()`

# %%
from random import *
def randomGap():
    return random() * 300 + 150   
print("randomGap() loaded!")

# %% [markdown]
# ### `gameReset()`

# %%
def gameReset():
    global gameActive, isGameOver, bird_posy, bird_vel, score, distance, bird_surf, bg_surf, pipes, lastPipe, bird_rect, speed, bird_acc, score_surf, score_rect, score_text, pipeDistance, gap_width, normal_text, start_surf, start_rect
    gameActive = isGameOver = False
    bird_posy = 300
    bird_vel = -10   
    pipeDistance = 300   
    gap_width = 250   
    speed = 3  
    bird_acc = 0.5   
    score = distance = lastPipe = 0
    score_text = pygame.font.Font(None, 100)
    score_surf = score_text.render(str(score), True, "Black")
    score_rect = score_surf.get_rect(center = (400, 50))
    pipes = []
    bird_surf = pygame.image.load('../graphics/bird.png')
    bird_rect = bird_surf.get_rect(center = (60, 300))
    bg_surf = pygame.image.load("../graphics/bg.png")
    normal_text = pygame.font.Font(None, 50) 
    start_surf = normal_text.render("Press [Space] to Start!", True, "Blue")
    start_rect = start_surf.get_rect(center = (400, 250))
print("gameReset() loaded!")

# %% [markdown]
# ### `gameOver()`

# %%
def gameOver():
    global bird_vel, isGameOver, normal_text, lost_rect, lost_surf, scoreShow_rect, scoreShow_surf, glide, bird_surf, restart_rect, restart_surf
    bird_vel = -10
    isGameOver = True   
    lost_surf = normal_text.render("Game Over...", True, "Red")
    lost_rect = lost_surf.get_rect(center = (400, 280))
    scoreShow_surf = normal_text.render(f"Your Score: {score}", True, "Red")
    scoreShow_rect = scoreShow_surf.get_rect(center = (400, 320))
    bird_surf = pygame.image.load('../graphics/bird_dead.png')
    restart_surf = normal_text.render("Press [R] to Play Again", True, "Blue")
    restart_rect = restart_surf.get_rect(center = (400, 400))
print("gameOver() loaded!")

# %% [markdown]
# ### CLass - `pipe_data()`

# %%
class pipe_data():
    posx = 800
    scored = False
    
    def __init__(self):
        self.gap = randomGap()
        self.lower_surf = pygame.image.load('../graphics/pipe.png')
        self.upper_surf = pygame.transform.flip(pygame.image.load('../graphics/pipe.png'), False, True)
        self.upper_rect = self.upper_surf.get_rect(bottomleft = (800, self.gap - gap_width / 2))
        self.lower_rect = self.lower_surf.get_rect(topleft = (800, self.gap + gap_width / 2))
        
    def draw(self):
        screen.blit(self.upper_surf, self.upper_rect)
        screen.blit(self.lower_surf, self.lower_rect)

print("pipe_data() loaded!")

# %% [markdown]
# ### Main Game

# %%
import pygame
pygame.init()

screen = pygame.display.set_mode((800, 600))
running = True
clock = pygame.time.Clock()

gameReset()

screen.blit(bird_surf, bird_rect)

while running:
    screen.blit(bg_surf, (0, 0))    
    screen.blit(bird_surf, bird_rect)
    
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
            
        if event.type == pygame.KEYDOWN and event.key == pygame.K_SPACE and not isGameOver:
            jump()
                
        if event.type == pygame.KEYDOWN and event.key == pygame.K_r:
            gameReset()
        else:
            if event.type == pygame.KEYDOWN and event.key == pygame.K_SPACE:
                gameActive = True

### For 6.4, paste the code A here ###

######################################

    if gameActive:
        
        bird_vel += bird_acc
        bird_posy += bird_vel
        if bird_posy < 0:
            bird_vel = bird_posy = 0
        bird_rect.y = bird_posy

        for current in pipes:
            current.draw()
        if not isGameOver:
            for current in pipes:
                current.posx -= speed
                current.upper_rect.x = current.lower_rect.x = current.posx
                if not current.scored and current.posx < 0:
                    score += 1
                    current.scored = True
                
                if current.posx < -60:
                    pipes.remove(current)
                    
                if current.upper_rect.colliderect(bird_rect) or current.lower_rect.colliderect(bird_rect):
                    gameOver()
                    
            if distance - lastPipe >= pipeDistance:
                lastPipe = distance
                pipes.append(pipe_data())
                
            distance += speed
    
            if bird_posy > 550:
                gameOver()
        else:
            screen.blit(lost_surf, lost_rect)
            screen.blit(scoreShow_surf, scoreShow_rect)
            screen.blit(restart_surf, restart_rect)
            speed = 0
    else: 
        screen.blit(start_surf, start_rect)
        
    score_surf = score_text.render(str(score), 100, "Black")
    score_rect = score_surf.get_rect(center = (400, 50))
    screen.blit(score_surf, score_rect)
    pygame.display.update()                 
    clock.tick(60)                       
    
pygame.quit()

# %% [markdown]
# ## 6.1 Bonus I - Increasing Difficulty
# For now, the game is a little bit too easy.<br>
# Let's make it more challenging by making it progressionally faster!<br>
# In order words, the player moves faster everytime he/she scores.
# <hr>
#
# How fast the player moves is defined by the variable `speed`.<br>
# By increasing it, we can make it move faster!<br>
# Copy the following line and paste it at a suitable space in the final game to implement this feature:<br>
# ```python
# speed += 0.1
# ```
# If you want, you can also change how much the speed is increased every time the player scores.<br>
# Try again with larger values if you think the change is not significant!<br>
# ```python
# speed += 1
# ```
# To make it even more challenging, we can change it from addition, to multiplication:<br>
# ```python
# speed *= 1.2
# ```
# _For your information, the initial speed value is `3`_.

# %% [markdown]
# ### Answer

# %% [markdown]
# Changes are marked with `###`

# %%
import pygame
pygame.init()
print("Pygame imported!")

def jump():
    global bird_vel
    bird_vel = -10   
print("jump() loaded!")

from random import *
def randomGap():
    return random() * 300 + 150   
print("randomGap() loaded!")

def gameReset():
    global gameActive, isGameOver, bird_posy, bird_vel, score, distance, bird_surf, bg_surf, pipes, lastPipe, bird_rect, speed, bird_acc, score_surf, score_rect, score_text, pipeDistance, gap_width, normal_text, start_surf, start_rect
    gameActive = isGameOver = False
    bird_posy = 300
    bird_vel = -10   
    pipeDistance = 300   
    gap_width = 250   
    speed = 3  
    bird_acc = 0.5   
    score = distance = lastPipe = 0
    score_text = pygame.font.Font(None, 100)
    score_surf = score_text.render(str(score), True, "Black")
    score_rect = score_surf.get_rect(center = (400, 50))
    pipes = []
    bird_surf = pygame.image.load('../graphics/bird.png')
    bird_rect = bird_surf.get_rect(center = (60, 300))
    bg_surf = pygame.image.load("../graphics/bg.png")
    normal_text = pygame.font.Font(None, 50) 
    start_surf = normal_text.render("Press [Space] to Start!", True, "Blue")
    start_rect = start_surf.get_rect(center = (400, 250))
print("gameReset() loaded!")

def gameOver():
    global bird_vel, isGameOver, normal_text, lost_rect, lost_surf, scoreShow_rect, scoreShow_surf, glide, bird_surf, restart_rect, restart_surf
    bird_vel = -10
    isGameOver = True   
    lost_surf = normal_text.render("Game Over...", True, "Red")
    lost_rect = lost_surf.get_rect(center = (400, 280))
    scoreShow_surf = normal_text.render(f"Your Score: {score}", True, "Red")
    scoreShow_rect = scoreShow_surf.get_rect(center = (400, 320))
    bird_surf = pygame.image.load('../graphics/bird_dead.png')
    restart_surf = normal_text.render("Press [R] to Play Again", True, "Blue")
    restart_rect = restart_surf.get_rect(center = (400, 400))
print("gameOver() loaded!")

class pipe_data():
    posx = 800
    scored = False
    
    def __init__(self):
        self.gap = randomGap()
        self.lower_surf = pygame.image.load('../graphics/pipe.png')
        self.upper_surf = pygame.transform.flip(pygame.image.load('../graphics/pipe.png'), False, True)
        self.upper_rect = self.upper_surf.get_rect(bottomleft = (800, self.gap - gap_width / 2))
        self.lower_rect = self.lower_surf.get_rect(topleft = (800, self.gap + gap_width / 2))
        
    def draw(self):
        screen.blit(self.upper_surf, self.upper_rect)
        screen.blit(self.lower_surf, self.lower_rect)

print("pipe_data() loaded!")

screen = pygame.display.set_mode((800, 600))
running = True
clock = pygame.time.Clock()

gameReset()

screen.blit(bird_surf, bird_rect)

while running:
    screen.blit(bg_surf, (0, 0))    
    screen.blit(bird_surf, bird_rect)
    
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
            
        if event.type == pygame.KEYDOWN and event.key == pygame.K_SPACE and not isGameOver:
            jump()
                
        if event.type == pygame.KEYDOWN and event.key == pygame.K_r:
            gameReset()
        else:
            if event.type == pygame.KEYDOWN and event.key == pygame.K_SPACE:
                gameActive = True

    if gameActive:
        
        bird_vel += bird_acc
        bird_posy += bird_vel
        if bird_posy < 0:
            bird_vel = bird_posy = 0
        bird_rect.y = bird_posy

        for current in pipes:
            current.draw()
        if not isGameOver:
            for current in pipes:
                current.posx -= speed
                current.upper_rect.x = current.lower_rect.x = current.posx
                if not current.scored and current.posx < 0:
                    score += 1
                    speed += 0.1 ### Add this line
                    current.scored = True
                
                if current.posx < -60:
                    pipes.remove(current)
                    
                if current.upper_rect.colliderect(bird_rect) or current.lower_rect.colliderect(bird_rect):
                    gameOver()
                    
            if distance - lastPipe >= pipeDistance:
                lastPipe = distance
                pipes.append(pipe_data())
                
            distance += speed
    
            if bird_posy > 550:
                gameOver()
        else:
            screen.blit(lost_surf, lost_rect)
            screen.blit(scoreShow_surf, scoreShow_rect)
            screen.blit(restart_surf, restart_rect)
            speed = 0
    else: 
        screen.blit(start_surf, start_rect)
        
    score_surf = score_text.render(str(score), 100, "Black")
    score_rect = score_surf.get_rect(center = (400, 50))
    screen.blit(score_surf, score_rect)
    pygame.display.update()                 
    clock.tick(60)                       
    
pygame.quit()
# Out:
# pygame 2.4.0 (SDL 2.26.4, Python 3.11.4)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Pygame imported!
# jump() loaded!
# randomGap() loaded!
# gameReset() loaded!
# gameOver() loaded!
# pipe_data() loaded!

# %% [markdown]
# ## 6.2 Bonus II - Speedometer
# Now that we have varying speed, let's add a speedometer to let the player know how fast he/she is going.<br>
# The following code creates and displays a speedometer in km/h with 1 decimal place in black with anti-aliasing.<br>
# Copy it and paste it at a suitable place:
# ```python
#     speed_surf = normal_text.render(f"{speed:.1f} km/h", True, "Black")
#     speed_rect = speed_surf.get_rect(bottomright = (775, 575))
#     screen.blit(speed_surf, speed_rect)
# ```
# You can either change the decimal places, the unit, the colour, anti-aliasing, or the position of the speedometer.<br>
# For example:
# ```python
#     speed_surf = normal_text.render(f"{speed:.2f} m/s", False, "Red")
#     speed_rect = speed_surf.get_rect(topleft = (25, 25))
#     screen.blit(speed_surf, speed_rect)
# ```

# %% [markdown]
# ### Answer

# %% [markdown]
# Changes are marked with `###`

# %%
import pygame
pygame.init()
print("Pygame imported!")

def jump():
    global bird_vel
    bird_vel = -10   
print("jump() loaded!")

from random import *
def randomGap():
    return random() * 300 + 150   
print("randomGap() loaded!")

def gameReset():
    global gameActive, isGameOver, bird_posy, bird_vel, score, distance, bird_surf, bg_surf, pipes, lastPipe, bird_rect, speed, bird_acc, score_surf, score_rect, score_text, pipeDistance, gap_width, normal_text, start_surf, start_rect
    gameActive = isGameOver = False
    bird_posy = 300
    bird_vel = -10   
    pipeDistance = 300   
    gap_width = 250   
    speed = 3  
    bird_acc = 0.5   
    score = distance = lastPipe = 0
    score_text = pygame.font.Font(None, 100)
    score_surf = score_text.render(str(score), True, "Black")
    score_rect = score_surf.get_rect(center = (400, 50))
    pipes = []
    bird_surf = pygame.image.load('../graphics/bird.png')
    bird_rect = bird_surf.get_rect(center = (60, 300))
    bg_surf = pygame.image.load("../graphics/bg.png")
    normal_text = pygame.font.Font(None, 50) 
    start_surf = normal_text.render("Press [Space] to Start!", True, "Blue")
    start_rect = start_surf.get_rect(center = (400, 250))
print("gameReset() loaded!")

def gameOver():
    global bird_vel, isGameOver, normal_text, lost_rect, lost_surf, scoreShow_rect, scoreShow_surf, glide, bird_surf, restart_rect, restart_surf
    bird_vel = -10
    isGameOver = True   
    lost_surf = normal_text.render("Game Over...", True, "Red")
    lost_rect = lost_surf.get_rect(center = (400, 280))
    scoreShow_surf = normal_text.render(f"Your Score: {score}", True, "Red")
    scoreShow_rect = scoreShow_surf.get_rect(center = (400, 320))
    bird_surf = pygame.image.load('../graphics/bird_dead.png')
    restart_surf = normal_text.render("Press [R] to Play Again", True, "Blue")
    restart_rect = restart_surf.get_rect(center = (400, 400))
print("gameOver() loaded!")

class pipe_data():
    posx = 800
    scored = False
    
    def __init__(self):
        self.gap = randomGap()
        self.lower_surf = pygame.image.load('../graphics/pipe.png')
        self.upper_surf = pygame.transform.flip(pygame.image.load('../graphics/pipe.png'), False, True)
        self.upper_rect = self.upper_surf.get_rect(bottomleft = (800, self.gap - gap_width / 2))
        self.lower_rect = self.lower_surf.get_rect(topleft = (800, self.gap + gap_width / 2))
        
    def draw(self):
        screen.blit(self.upper_surf, self.upper_rect)
        screen.blit(self.lower_surf, self.lower_rect)

print("pipe_data() loaded!")

screen = pygame.display.set_mode((800, 600))
running = True
clock = pygame.time.Clock()

gameReset()

screen.blit(bird_surf, bird_rect)

while running:
    screen.blit(bg_surf, (0, 0))    
    screen.blit(bird_surf, bird_rect)
    
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
            
        if event.type == pygame.KEYDOWN and event.key == pygame.K_SPACE and not isGameOver:
            jump()
                
        if event.type == pygame.KEYDOWN and event.key == pygame.K_r:
            gameReset()
        else:
            if event.type == pygame.KEYDOWN and event.key == pygame.K_SPACE:
                gameActive = True

    if gameActive:
        
        bird_vel += bird_acc
        bird_posy += bird_vel
        if bird_posy < 0:
            bird_vel = bird_posy = 0
        bird_rect.y = bird_posy

        for current in pipes:
            current.draw()
        if not isGameOver:
            for current in pipes:
                current.posx -= speed
                current.upper_rect.x = current.lower_rect.x = current.posx
                if not current.scored and current.posx < 0:
                    score += 1
                    speed += 0.1
                    current.scored = True
                
                if current.posx < -60:
                    pipes.remove(current)
                    
                if current.upper_rect.colliderect(bird_rect) or current.lower_rect.colliderect(bird_rect):
                    gameOver()
                    
            if distance - lastPipe >= pipeDistance:
                lastPipe = distance
                pipes.append(pipe_data())
                
            distance += speed
    
            if bird_posy > 550:
                gameOver()
        else:
            screen.blit(lost_surf, lost_rect)
            screen.blit(scoreShow_surf, scoreShow_rect)
            screen.blit(restart_surf, restart_rect)
            speed = 0
    else: 
        screen.blit(start_surf, start_rect)
        
    score_surf = score_text.render(str(score), 100, "Black")
    score_rect = score_surf.get_rect(center = (400, 50))
    screen.blit(score_surf, score_rect)
    speed_surf = normal_text.render(f"{speed:.1f} km/h", True, "Black")   ### Added this line
    speed_rect = speed_surf.get_rect(bottomright = (775, 575))            ### Added this line
    screen.blit(speed_surf, speed_rect)                                   ### Added this line
    pygame.display.update()                 
    clock.tick(60)                       
    
pygame.quit()
# Out:
# pygame 2.4.0 (SDL 2.26.4, Python 3.11.4)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Pygame imported!
# jump() loaded!
# randomGap() loaded!
# gameReset() loaded!
# gameOver() loaded!
# pipe_data() loaded!

# %% [markdown]
# ## 6.3 Bonus III - Special Pipe

# %% [markdown]
# There are only green pipes, and that's a little bit boring.<br>
# Let's add a new type of pipe! It should have:<br>
# * More points
# * More speed increase
# * Different texture
# * Narrower gap<br><br>
# Most of the code has been done for you. However, you have to fill in one missing item:<br>
# The condition of spawning the special pipe (e.g. 5% chance).<br>
# To randomize this process, we use the `random()` function.<br>
# Fill in the brackets below and run the code!<br>
# <br>
# Reminder: $0 ⩽ random() < 1$

# %%
class pipe_data():
    posx = 800
    scored = False
    special = False
    
    def __init__(self):
        self.gap = randomGap()
                    #####################################################
        if (   ):   # <<< Add a comparison statement with random() here #
                    #####################################################
            # Special pipe
            self.special = True
            self.lower_surf = pygame.image.load('../graphics/pipe_sp.png')   # Uses a different texture
            self.upper_surf = pygame.transform.flip(pygame.image.load('../graphics/pipe_sp.png'), False, True)
            self.upper_rect = self.upper_surf.get_rect(bottomleft = (800, self.gap - gap_width / 3))   # Narrower gaps
            self.lower_rect = self.lower_surf.get_rect(topleft = (800, self.gap + gap_width / 3))
        else:
            # Normal pipe
            self.lower_surf = pygame.image.load('../graphics/pipe.png')
            self.upper_surf = pygame.transform.flip(pygame.image.load('../graphics/pipe.png'), False, True)
            self.upper_rect = self.upper_surf.get_rect(bottomleft = (800, self.gap - gap_width / 2))
            self.lower_rect = self.lower_surf.get_rect(topleft = (800, self.gap + gap_width / 2))
        
    def draw(self):
        screen.blit(self.upper_surf, self.upper_rect)
        screen.blit(self.lower_surf, self.lower_rect)

print("pipe_data() loaded!")
# Out:
# pipe_data() loaded!

# %% [markdown]
# After that, replace 2 lines in the main game with the following code, then run the game again: (Use `Ctrl` + `A` !)<br>
# (But not running the following cell directly!)

# %%
                    if current.special:
                        score += 5    # Add 5 points if the pipe is special
                        speed += 0.5  # Add 0.5 speed after that
                    else:
                        score += 1    # Add 1 point if the pipe is not special
                        speed += 0.1  # Add 0.1 speed after that

# %% [markdown]
# ### Answer

# %% [markdown]
# Changes are marked with `###`

# %%
import pygame
pygame.init()
print("Pygame imported!")

def jump():
    global bird_vel
    bird_vel = -10   
print("jump() loaded!")

from random import *
def randomGap():
    return random() * 300 + 150   
print("randomGap() loaded!")

def gameReset():
    global gameActive, isGameOver, bird_posy, bird_vel, score, distance, bird_surf, bg_surf, pipes, lastPipe, bird_rect, speed, bird_acc, score_surf, score_rect, score_text, pipeDistance, gap_width, normal_text, start_surf, start_rect
    gameActive = isGameOver = False
    bird_posy = 300
    bird_vel = -10   
    pipeDistance = 300   
    gap_width = 250   
    speed = 3  
    bird_acc = 0.5   
    score = distance = lastPipe = 0
    score_text = pygame.font.Font(None, 100)
    score_surf = score_text.render(str(score), True, "Black")
    score_rect = score_surf.get_rect(center = (400, 50))
    pipes = []
    bird_surf = pygame.image.load('../graphics/bird.png')
    bird_rect = bird_surf.get_rect(center = (60, 300))
    bg_surf = pygame.image.load("../graphics/bg.png")
    normal_text = pygame.font.Font(None, 50) 
    start_surf = normal_text.render("Press [Space] to Start!", True, "Blue")
    start_rect = start_surf.get_rect(center = (400, 250))
print("gameReset() loaded!")

def gameOver():
    global bird_vel, isGameOver, normal_text, lost_rect, lost_surf, scoreShow_rect, scoreShow_surf, glide, bird_surf, restart_rect, restart_surf
    bird_vel = -10
    isGameOver = True   
    lost_surf = normal_text.render("Game Over...", True, "Red")
    lost_rect = lost_surf.get_rect(center = (400, 280))
    scoreShow_surf = normal_text.render(f"Your Score: {score}", True, "Red")
    scoreShow_rect = scoreShow_surf.get_rect(center = (400, 320))
    bird_surf = pygame.image.load('../graphics/bird_dead.png')
    restart_surf = normal_text.render("Press [R] to Play Again", True, "Blue")
    restart_rect = restart_surf.get_rect(center = (400, 400))
print("gameOver() loaded!")

class pipe_data():
    posx = 800
    scored = False
    special = False
    
    def __init__(self):
        self.gap = randomGap()
        if random() < 0.05:      ### Added this conditional
            self.special = True
            self.lower_surf = pygame.image.load('../graphics/pipe_sp.png')  
            self.upper_surf = pygame.transform.flip(pygame.image.load('../graphics/pipe_sp.png'), False, True)
            self.upper_rect = self.upper_surf.get_rect(bottomleft = (800, self.gap - gap_width / 3))  
            self.lower_rect = self.lower_surf.get_rect(topleft = (800, self.gap + gap_width / 3))
        else:
            # Normal pipe
            self.lower_surf = pygame.image.load('../graphics/pipe.png')
            self.upper_surf = pygame.transform.flip(pygame.image.load('../graphics/pipe.png'), False, True)
            self.upper_rect = self.upper_surf.get_rect(bottomleft = (800, self.gap - gap_width / 2))
            self.lower_rect = self.lower_surf.get_rect(topleft = (800, self.gap + gap_width / 2))
        
    def draw(self):
        screen.blit(self.upper_surf, self.upper_rect)
        screen.blit(self.lower_surf, self.lower_rect)

print("pipe_data() loaded!")

screen = pygame.display.set_mode((800, 600))
running = True
clock = pygame.time.Clock()

gameReset()

screen.blit(bird_surf, bird_rect)

while running:
    screen.blit(bg_surf, (0, 0))    
    screen.blit(bird_surf, bird_rect)
    
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
            
        if event.type == pygame.KEYDOWN and event.key == pygame.K_SPACE and not isGameOver:
            jump()
                
        if event.type == pygame.KEYDOWN and event.key == pygame.K_r:
            gameReset()
        else:
            if event.type == pygame.KEYDOWN and event.key == pygame.K_SPACE:
                gameActive = True

    if gameActive:
        
        bird_vel += bird_acc
        bird_posy += bird_vel
        if bird_posy < 0:
            bird_vel = bird_posy = 0
        bird_rect.y = bird_posy

        for current in pipes:
            current.draw()
        if not isGameOver:
            for current in pipes:
                current.posx -= speed
                current.upper_rect.x = current.lower_rect.x = current.posx
                if not current.scored and current.posx < 0:
                    
                    if current.special:    ### Added this conditional
                        score += 5   
                        speed += 0.5 
                    else:
                        score += 1    
                        speed += 0.1 
                        
                    current.scored = True
                
                if current.posx < -60:
                    pipes.remove(current)
                    
                if current.upper_rect.colliderect(bird_rect) or current.lower_rect.colliderect(bird_rect):
                    gameOver()
                    
            if distance - lastPipe >= pipeDistance:
                lastPipe = distance
                pipes.append(pipe_data())
                
            distance += speed
    
            if bird_posy > 550:
                gameOver()
        else:
            screen.blit(lost_surf, lost_rect)
            screen.blit(scoreShow_surf, scoreShow_rect)
            screen.blit(restart_surf, restart_rect)
            speed = 0
    else: 
        screen.blit(start_surf, start_rect)
        
    score_surf = score_text.render(str(score), 100, "Black")
    score_rect = score_surf.get_rect(center = (400, 50))
    screen.blit(score_surf, score_rect)
    pygame.display.update()                 
    clock.tick(60)                       
    
pygame.quit()

# %% [markdown]
# ## 6.4 Bonus IV - Glide Feature

# %% [markdown]
# For now, we are just using `Space`.<br>
# Let's add a feature that is activated with `Shift` - Glide.<br>
# When glide mode is activated:<br>
# * Maximum downward velocity is set to 1
# * Speed of the player gradually increases<br>
# <hr>
# To accomplish that, we first need to add a new varible `glide` to indicate whether the player is gliding.<br>
# Run the following code to initiate `glide` as `False`:

# %%
def gameReset():
    global gameActive, isGameOver, bird_posy, bird_vel, score, distance, bird_surf, bg_surf, pipes, lastPipe, bird_rect, speed, bird_acc, score_surf, score_rect, score_text, pipeDistance, gap_width, normal_text, start_surf, start_rect, glide ### Changed this line
    gameActive = isGameOver = False
    bird_posy = 300
    bird_vel = -10   
    pipeDistance = 300   
    gap_width = 250   
    speed = 3  
    bird_acc = 0.5   
    score = distance = lastPipe = 0
    score_text = pygame.font.Font(None, 100)
    score_surf = score_text.render(str(score), True, "Black")
    score_rect = score_surf.get_rect(center = (400, 50))
    pipes = []
    bird_surf = pygame.image.load('../graphics/bird.png')
    bird_rect = bird_surf.get_rect(center = (60, 300))
    bg_surf = pygame.image.load("../graphics/bg.png")
    normal_text = pygame.font.Font(None, 50) 
    start_surf = normal_text.render("Press [Space] to Start!", True, "Blue")
    start_rect = start_surf.get_rect(center = (400, 250))
    glide = False   ### Added this line
print("gameReset() loaded!")

def gameOver():
    global bird_vel, isGameOver, normal_text, lost_rect, lost_surf, scoreShow_rect, scoreShow_surf, glide, bird_surf, restart_rect, restart_surf, glide # Changed this line
    bird_vel = -10
    isGameOver = True   
    lost_surf = normal_text.render("Game Over...", True, "Red")
    lost_rect = lost_surf.get_rect(center = (400, 280))
    scoreShow_surf = normal_text.render(f"Your Score: {score}", True, "Red")
    scoreShow_rect = scoreShow_surf.get_rect(center = (400, 320))
    bird_surf = pygame.image.load('../graphics/bird_dead.png')
    restart_surf = normal_text.render("Press [R] to Play Again", True, "Blue")
    restart_rect = restart_surf.get_rect(center = (400, 400))
    glide = False   ### Added this line
print("gameOver() loaded!")
# Out:
# gameReset() loaded!
# gameOver() loaded!

# %% [markdown]
# <hr>
#
# Then copy the following code and paste it to the indicated space in the main game: (Use `Ctrl` + `A`!)

# %%
# Code A #
        if event.type == pygame.KEYDOWN and event.key == pygame.K_LSHIFT and not isGameOver: 
            
            # Run when [Shift] is pressed and game hasn't ended
            glide = True                                                # Set glide indicator to True
            bird_surf = pygame.image.load('../graphics/bird_glide.png') # Change the player appearance
            
        if event.type == pygame.KEYUP and event.key == pygame.K_LSHIFT and not isGameOver:             
            
            # Run when [Shift] is released and game hasn't ended
            glide = False                                               # Set glide indicator to False
            bird_surf = pygame.image.load('../graphics/bird.png')       # Change the player appearance back
            speed = 3 + score / 10                                      # Recalculate the speed

# %% [markdown]
# <hr>
#
# Now, add the following code to a suitable space in the main game to change the physics of the player when gliding is on:<br>
# ```python
#         if glide:
#             bird_vel = min(1, bird_vel)   ### Limit the maximum downward velocity to 1
#             speed += 0.05                 ### Add speed continously
# ```

# %% [markdown]
# ### Answer

# %% [markdown]
# Changes are marked with `###`

# %%
import pygame
pygame.init()
print("Pygame imported!")

def jump():
    global bird_vel
    bird_vel = -10   
print("jump() loaded!")

from random import *
def randomGap():
    return random() * 300 + 150   
print("randomGap() loaded!")

def gameReset():
    global gameActive, isGameOver, bird_posy, bird_vel, score, distance, bird_surf, bg_surf, pipes, lastPipe, bird_rect, speed, bird_acc, score_surf, score_rect, score_text, pipeDistance, gap_width, normal_text, start_surf, start_rect, glide ### Changed this line
    gameActive = isGameOver = False
    bird_posy = 300
    bird_vel = -10   
    pipeDistance = 300   
    gap_width = 250   
    speed = 3  
    bird_acc = 0.5   
    score = distance = lastPipe = 0
    score_text = pygame.font.Font(None, 100)
    score_surf = score_text.render(str(score), True, "Black")
    score_rect = score_surf.get_rect(center = (400, 50))
    pipes = []
    bird_surf = pygame.image.load('../graphics/bird.png')
    bird_rect = bird_surf.get_rect(center = (60, 300))
    bg_surf = pygame.image.load("../graphics/bg.png")
    normal_text = pygame.font.Font(None, 50) 
    start_surf = normal_text.render("Press [Space] to Start!", True, "Blue")
    start_rect = start_surf.get_rect(center = (400, 250))
    glide = False   ### Added this line
print("gameReset() loaded!")

def gameOver():
    global bird_vel, isGameOver, normal_text, lost_rect, lost_surf, scoreShow_rect, scoreShow_surf, glide, bird_surf, restart_rect, restart_surf, glide # Changed this line
    bird_vel = -10
    isGameOver = True   
    lost_surf = normal_text.render("Game Over...", True, "Red")
    lost_rect = lost_surf.get_rect(center = (400, 280))
    scoreShow_surf = normal_text.render(f"Your Score: {score}", True, "Red")
    scoreShow_rect = scoreShow_surf.get_rect(center = (400, 320))
    bird_surf = pygame.image.load('../graphics/bird_dead.png')
    restart_surf = normal_text.render("Press [R] to Play Again", True, "Blue")
    restart_rect = restart_surf.get_rect(center = (400, 400))
    glide = False   ### Added this line
print("gameOver() loaded!")

class pipe_data():
    posx = 800
    scored = False
    special = False
    
    def __init__(self):
        self.gap = randomGap()
        if random() < 0.05:
            self.special = True
            self.lower_surf = pygame.image.load('../graphics/pipe_sp.png')  
            self.upper_surf = pygame.transform.flip(pygame.image.load('../graphics/pipe_sp.png'), False, True)
            self.upper_rect = self.upper_surf.get_rect(bottomleft = (800, self.gap - gap_width / 3))  
            self.lower_rect = self.lower_surf.get_rect(topleft = (800, self.gap + gap_width / 3))
        else:
            # Normal pipe
            self.lower_surf = pygame.image.load('../graphics/pipe.png')
            self.upper_surf = pygame.transform.flip(pygame.image.load('../graphics/pipe.png'), False, True)
            self.upper_rect = self.upper_surf.get_rect(bottomleft = (800, self.gap - gap_width / 2))
            self.lower_rect = self.lower_surf.get_rect(topleft = (800, self.gap + gap_width / 2))
        
    def draw(self):
        screen.blit(self.upper_surf, self.upper_rect)
        screen.blit(self.lower_surf, self.lower_rect)

print("pipe_data() loaded!")

import pygame
pygame.init()

screen = pygame.display.set_mode((800, 600))
running = True
clock = pygame.time.Clock()

gameReset()

screen.blit(bird_surf, bird_rect)

while running:
    screen.blit(bg_surf, (0, 0))    
    screen.blit(bird_surf, bird_rect)
    
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
            
        if event.type == pygame.KEYDOWN and event.key == pygame.K_SPACE and not isGameOver:
            jump()
                
        if event.type == pygame.KEYDOWN and event.key == pygame.K_r:
            gameReset()
        else:
            if event.type == pygame.KEYDOWN and event.key == pygame.K_SPACE:
                gameActive = True

        if event.type == pygame.KEYDOWN and not isGameOver:   ### Added this conditional
            if event.key == pygame.K_LSHIFT:
                glide = True
                bird_surf = pygame.image.load('../graphics/bird_glide.png')
        if event.type == pygame.KEYUP and not isGameOver:     ### Added this conditional
            if event.key == pygame.K_LSHIFT:
                glide = False
                bird_surf = pygame.image.load('../graphics/bird.png')
                speed = 3 + score / 10
        
    if gameActive:
        
        bird_vel += bird_acc

        if glide:   ### Added this conditional
            bird_vel = min(1, bird_vel)
            speed += 0.05
        
        bird_posy += bird_vel
        if bird_posy < 0:
            bird_vel = bird_posy = 0
        bird_rect.y = bird_posy

        for current in pipes:
            current.draw()
        if not isGameOver:
            for current in pipes:
                current.posx -= speed
                current.upper_rect.x = current.lower_rect.x = current.posx
                if not current.scored and current.posx < 0:
                    
                    if current.special:
                        score += 5   
                        speed += 0.5 
                    else:
                        score += 1    
                        speed += 0.1 
                        
                    current.scored = True
                
                if current.posx < -60:
                    pipes.remove(current)
                    
                if current.upper_rect.colliderect(bird_rect) or current.lower_rect.colliderect(bird_rect):
                    gameOver()
                    
            if distance - lastPipe >= pipeDistance:
                lastPipe = distance
                pipes.append(pipe_data())
                
            distance += speed
    
            if bird_posy > 550:
                gameOver()
        else:
            screen.blit(lost_surf, lost_rect)
            screen.blit(scoreShow_surf, scoreShow_rect)
            screen.blit(restart_surf, restart_rect)
            speed = 0
    else: 
        screen.blit(start_surf, start_rect)
        
    score_surf = score_text.render(str(score), 100, "Black")
    score_rect = score_surf.get_rect(center = (400, 50))
    screen.blit(score_surf, score_rect)
    speed_surf = normal_text.render(f"{speed:.1f} km/h", True, "Black")
    speed_rect = speed_surf.get_rect(bottomright = (775, 575))
    screen.blit(speed_surf, speed_rect)
    pygame.display.update()                 
    clock.tick(60)                       
    
pygame.quit()
# Out:
# Pygame imported!
# jump() loaded!
# randomGap() loaded!
# gameReset() loaded!
# gameOver() loaded!
# pipe_data() loaded!
